# %% [markdown]
# # Assignment 2: Milestone I Natural Language Processing
# ## Task 2&3
# #### Student Name: Shiv Mahesh Bhosale
# #### Student ID: S4192953
#
#
# Environment: Python 397 and Jupyter notebook
#
# Libraries used: please include all the libraries you used in your assignment, e.g.,:
# * pandas
# * re
# * numpy
#
# ## Introduction
# You should give a brief information of this assessment task here.
#
# <span style="color: red"> Note that this is a sample notebook only. You will need to fill in the proper markdown and code blocks. You might also want to make necessary changes to the structure to meet your own needs. Note also that any generic comments written in this notebook are to be removed and replace with your own words.</span>

# %% [markdown]
# ## Importing libraries

# %%
# import pandas as pd
# import numpy as np
# import regex as re
from collections import Counter
from itertools import chain
import gensim
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import lil_matrix
import warnings
import logging

import gensim.downloader as api
warnings.filterwarnings('ignore')
import os

# %%
# !pip install pandas numpy scikit-learn gensim nltk
# Out:
# Requirement already satisfied: pandas in c:\users\shivb\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\shivb\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\shivb\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: gensim in c:\users\shivb\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: nltk in c:\users\shivb\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shivb\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shivb\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shivb\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\shivb\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shivb\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shivb\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\shivb\anaconda3\lib\site-packages (from gensim) (7.6.0)
# Requirement already satisfied: click in c:\users\shivb\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shivb\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\shivb\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\shivb\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in c:\users\shivb\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Requirement already satisfied: colorama in c:\users\shivb\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# C:\Users\shivb\anaconda3\envs\py397\python.exe
# 3.9.25 (main, Nov  3 2025, 22:44:01) [MSC v.1929 64 bit (AMD64)]

# %%
import sys
# !{sys.executable} -m pip install pandas numpy scikit-learn gensim nltk
# Out:
# Requirement already satisfied: pandas in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (2.0.2)
# Requirement already satisfied: scikit-learn in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (1.6.1)
# Requirement already satisfied: gensim in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (4.4.0)
# Requirement already satisfied: nltk in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: click in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: six>=1.5 in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Requirement already satisfied: colorama in c:\users\shivb\anaconda3\envs\py397\lib\site-packages (from click->nltk) (0.4.6)

# %%
# import pandas as pd
# import numpy as np
# from collections import Counter
# from itertools import chain
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.model_selection import cross_val_score
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import LinearSVC
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score
# import gensim.downloader as api
# import urllib.request
# import zipfile

# %% [markdown]
# ## Task 2. Generating Feature Representations for Clothing Items Reviews

# %% [markdown]
# ...... Sections and code blocks on buidling different document feature represetations
#
#
# <span style="color: red"> You might have complex notebook structure in this section, please feel free to create your own notebook structure. </span>

# %%
def load_vocab(filepath='vocab'):
    vocab = {}
    with open(filepath, 'r') as f:
        for line in f:
            line = line.strip()
            if ':' in line:
                word, idx = line.rsplit(':', 1)
                vocab[word] = int(idx)
    return vocab

# %%
vocab = load_vocab('vocab.txt')
index_to_word = {idx: word for word, idx in vocab.items()}

# %%
print(f"Vocabulary size: {len(vocab)}")
print(f"\nFirst 10 vocab entries:")
for word, idx in list(vocab.items())[:10]:
    print(f"  {word}:{idx}")
# Out:
# Vocabulary size: 8018
#
# First 10 vocab entries:
#   a-cup:0
#   a-flutter:1
#   a-frame:2
#   a-kind:3
#   a-line:4
#   a-lines:5
#   a-symmetric:6
#   aa:7
#   ab:8
#   abbey:9

# %%
df = pd.read_csv('processed.csv')

# %%
df
# Out:
#        Clothing ID  Age                                              Title  \
# 0             1077   60                            Some major design flaws
# 1             1049   50                                   My favorite buy!
# 2              847   47                                   Flattering shirt
# 3             1080   49                            Not for the very petite
# 4              858   39                               Cagrcoal shimmer fun
# ...            ...  ...                                                ...
# 19657         1104   34                     Great dress for many occasions
# 19658          862   48                         Wish it was made of cotton
# 19659         1104   31                              Cute, but see through
# 19660         1084   28  Very cute dress, perfect for summer parties an...
# 19661         1104   52                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      had such high hopes for this dress and really ...       3
# 1      love love love this jumpsuit it's fun flirty a...       5
# 2      this shirt is very flattering to all due to th...       5
# 3      love tracy reese dresses but this one is not f...       2
# 4      this in my basket at hte last to see what it w...       5
# ...                                                  ...     ...
# 19657  was very happy to snag this dress at such grea...       5
# 19658  it reminds me of maternity clothes soft stretc...       3
# 19659  this fit well but the top was very see through...       3
# 19660  bought this dress for wedding have this summer...       3
# 19661  this dress in lovely is feminine and fits perf...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    0                        0         General
# 1                    1                        0  General Petite
# 2                    1                        6         General
# 3                    0                        4         General
# 4                    1                        1  General Petite
# ...                ...                      ...             ...
# 19657                1                        0  General Petite
# 19658                1                        0  General Petite
# 19659                0                        1  General Petite
# 19660                1                        2         General
# 19661                1                       22  General Petite
#
#       Department Name Class Name
# 0             Dresses    Dresses
# 1             Bottoms      Pants
# 2                Tops    Blouses
# 3             Dresses    Dresses
# 4                Tops      Knits
# ...               ...        ...
# 19657         Dresses    Dresses
# 19658            Tops      Knits
# 19659         Dresses    Dresses
# 19660         Dresses    Dresses
# 19661         Dresses    Dresses
#
# [19662 rows x 10 columns]

# %%
df["Review Text"].isnull().sum()
# Out:
# np.int64(0)

# %%
tk_reviews = [review.split(' ') for review in df['Review Text'].tolist()]

# %%
tk_reviews[1]
# Out:
# ['love',
#  'love',
#  'love',
#  'this',
#  'jumpsuit',
#  "it's",
#  'fun',
#  'flirty',
#  'and',
#  'fabulous',
#  'every',
#  'time',
#  'wear',
#  'it',
#  'get',
#  'nothing',
#  'but',
#  'great',
#  'compliments']

# %%
joined_reviews = [' '.join(tokens) for tokens in tk_reviews]

# %%
joined_reviews[1]
# Out:
# "love love love this jumpsuit it's fun flirty and fabulous every time wear it get nothing but great compliments"

# %%
len(tk_reviews)
# Out:
# 19662

# %%
cVectorizer = CountVectorizer(analyzer="word", vocabulary=vocab)
count_features = cVectorizer.fit_transform(joined_reviews)

# %%
count_features.shape
# Out:
# (19662, 8018)

# %%
out_file = open('count_vectors.txt', 'w')

# %%
for doc_id in range(count_features.shape[0]):
    row = count_features[doc_id].tocoo()
    pairs = ','.join(
        f"{col}:{val}"
        for col, val in sorted(zip(row.col, row.data))
    )
    out_file.write(f"#{doc_id},{pairs}\n")
out_file.close()

# %%
with open('count_vectors.txt') as f:
    lines = f.read().splitlines()

# %%
len(lines)
# Out:
# 19662

# %%
lines[0]
# Out:
# '#0,227:3,516:1,757:1,923:2,1112:1,1332:1,1504:1,1820:1,1900:1,2061:1,2427:1,2579:1,2627:1,2721:2,2754:1,3056:2,3062:2,3197:1,3277:1,3392:1,3414:2,3462:1,3518:1,3553:4,3623:1,3775:2,3778:1,4071:1,4156:1,4179:1,4423:1,4487:2,4502:1,4548:1,4627:1,4693:1,4726:1,4735:2,4742:1,4947:2,5446:1,5584:1,6007:1,6014:1,6218:1,6315:3,6371:1,6411:1,6756:1,7028:1,7033:5,7084:2,7135:1,7169:2,7195:1,7396:1,7490:1,7525:1,7579:1,7647:1,7669:3,7782:1,7886:1,8009:1,8011:1'

# %%
tVectorizer = TfidfVectorizer(analyzer="word", vocabulary=vocab)
tfidf_features = tVectorizer.fit_transform(joined_reviews)

# %%
tfidf_features.shape
# Out:
# (19662, 8018)

# %%
sample = tfidf_features[0].tocoo()
top = sorted(zip(sample.col, sample.data), key=lambda x: -x[1])[:8]

print("Top TF-IDF words in review 0:")
for index, score in top:
    print(f"  '{index_to_word[int(index)]}': {score:.4f}")
# Out:
# Top TF-IDF words in review 0:
#   'net': 0.4086
#   'half': 0.2517
#   'layer': 0.2299
#   'outrageously': 0.2155
#   'directly': 0.1850
#   'small': 0.1840
#   'over': 0.1704
#   'reordered': 0.1688

# %%
embedding_model = api.load('glove-wiki-gigaword-100')

# %%
embedding_dim = embedding_model.vector_size
print('Embedding dimension:', embedding_dim)

# %%
def getDocVec_unweighted(review, model, vec_size):
    vectors = []
    for w in review:
        if w in model:
            vectors.append(model[w])
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(vec_size)

# %%
unweighted_doc_vectors = np.array(
    [getDocVec_unweighted(review, embedding_model, embedding_dim) 
     for review in tk_reviews]
)
unweighted_doc_vectors.shape

# %%
unweighted_doc_vectors[0]

# %%
print(unweighted_doc_vectors[0])

# %% [markdown]
# ### Saving outputs
# Save the count vector representation as per spectification.
# - count_vectors.txt

# %%
# code to save output data...

# %% [markdown]
# ## Task 3. Clothing Review Classification

# %% [markdown]
# ...... Sections and code blocks on buidling classification models based on different document feature represetations.
# Detailed comparsions and evaluations on different models to answer each question as per specification.
#
# <span style="color: red"> You might have complex notebook structure in this section, please feel free to create your own notebook structure. </span>

# %%
# Code to perform the task...

# %% [markdown]
# ## Summary
# Give a short summary and anything you would like to talk about the assessment tasks here.

# %% [markdown]
# ## Couple of notes for all code blocks in this notebook
# - please provide proper comment on your code
# - Please re-start and run all cells to make sure codes are runable and include your output in the submission.
# <span style="color: red"> This markdown block can be removed once the task is completed. </span>
